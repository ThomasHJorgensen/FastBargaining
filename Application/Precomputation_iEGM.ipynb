# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pickle
from time import time
from matplotlib import pyplot as plt

from DynamicTimeAllocationModel import HouseholdModelClass
from figure_manager import FigureManager

path = 'output/'

# c++ settings
do_compile = True
threads = 40

# from EconModel import cpptools
# cpptools.setup_nlopt(folder='cppfuncs/', do_print=True)

# %% [markdown]
# # Solve and simulate model

# %% [markdown]
# Load calibrated model [TODO]

# %%
settings = { 
       'T':30,
       'num_A': 15,
       'num_A_pd': 16,
       'num_K': 12,
       'num_power': 11,
       'num_love': 6,
       
       'max_A': 1_000.0,
       'max_A_pd': 1_000.0,
       'max_Ctot': 2_000.0,
       'max_K': 30.0,
       
       'init_couple_share': 0.77,
       
       'simT': 30,
       'simN': 10_000,

       'num_Ctot': 120,
       'num_marg_u':120,

       'phi': 1.0,
       'phi_mult': 1.0,
       
       'mu': 2.5,
       'mu_mult': 1.0,
       
       'gamma': 0.14,
       'gamma_mult': 1.0,
       
       'p_meet': 0.0,

       'threads':threads,
       'num_multistart': 2,
       
       'do_egm': True,
       'interp_method': 'linear',
       'interp_inverse': True,
       
       'precompute_intratemporal': True,
       'centered_gradient': True,
       
       
       
       
       'mu': 3.5172, 
       'mu_mult': 1.0,#1.0533,
       'gamma': 0.0677,
       'gamma_mult': 1.0,#1.1857,
       
       'eta'            : 2.85,
       'eta_mult'       : 1.0,
       'phi'            : 1.97,
       'phi_mult'       : 1.0,

       'alpha'          : 1.0,#1.18,
       'zeta'           : 0.40,
       'omega'          : 0.38,
       'pi'             : 0.5,
       
       'lambda_'        : 10.0,
       
       'sigma_love': 0.15,
       'div_cost': 0.0,
       }


# setup model
model = HouseholdModelClass(par=settings)
model.link_to_cpp(force_compile=do_compile)

# %%
test = np.ones(2,dtype=np.int_)
test.dtype # should be int32!
# Out:
# dtype('int32')

# %%
# version = int(np.__version__[0])
# import re
# re.search(r'\d+', version)
assert int(np.__version__[0])<2, f'Numpy must be before version 2'

# %%
# solve and simulate baseline model
model.solve()
# model.simulate()

# %% [markdown]
# # Illustrate precomputed interpolator

# %%
grid_C = model.par.grid_C_for_marg_u
grid_power = model.par.grid_power
grid_W = model.par.grid_Wpre

X, Y = np.meshgrid(grid_C, grid_power)

Xpre, Ypre = np.meshgrid(grid_W,grid_power )

min_C_idx = 1
ilw = -1
ilm = -1
grid_marg_u = model.sol.grid_marg_u_couple[ilw,ilm]

grid_Cinterp = model.sol.grid_Cinterp_couple[ilw,ilm]

fig = plt.figure()
ax = fig.add_subplot(projection='3d')  
ax.plot_surface(X[:,min_C_idx:], Y[:,min_C_idx:], grid_marg_u[:,min_C_idx:],alpha=0.7, cmap='viridis')
ax.set(xlabel=r'Consumption, $C$', ylabel=r'Power, $\mu$', zlim=(0.0, 0.6));
fig.savefig('output/application_iEGM_interp_W.pdf', bbox_inches='tight')


fig = plt.figure()
ax = fig.add_subplot(projection='3d')  
ax.plot_surface(grid_marg_u[:,min_C_idx:], Y[:,min_C_idx:], X[:,min_C_idx:],alpha=0.7, cmap='viridis')
ax.set(xlabel=r'Marg. val. of wealth, $W$', ylabel=r'Power, $\mu$');
fig.savefig('output/application_iEGM_interp_C.pdf', bbox_inches='tight')

fig = plt.figure()
ax = fig.add_subplot(projection='3d')  
ax.scatter(Xpre, Ypre, grid_Cinterp,color='black',marker='+')
ax.scatter(grid_marg_u[:,min_C_idx:], Y[:,min_C_idx:], X[:,min_C_idx:], color='r')
ax.set(xlabel=r'Marg. val. of wealth, $W$', ylabel=r'Power, $\mu$');
ax.set(zlim=(50.0,500.0));

# %%
stop

# %% [markdown]
# ## Productivity (human capital) shocks
# Introduce a large shock in a specific period

# %%
# print(model.par.num_power//2)
# print(model.par.grid_power)
# print(model.par.grid_power[5])

# %%
age_shock = 30 #agemin: 25
size_shock = 1.0
t_shock = age_shock-25

model_shock = model.copy()
# model_shock.sim.draw_shock_Kw[:,t_shock] = 1.0 + size_shock
model_shock.sim.draw_love[:,t_shock] = -5.0
model_shock.sim.draw_repartner_love[:,t_shock] = -5.0
# model_shock.sim.init_power_idx[:] = 1 # TESTING if the initial power is the cause
model_shock.simulate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 5
#       2 size_shock = 1.0
#       3 t_shock = age_shock-25
# ----> 5 model_shock = model.copy()
#       6 # model_shock.sim.draw_shock_Kw[:,t_shock] = 1.0 + size_shock
#       7 model_shock.sim.draw_love[:,t_shock] = -5.0
#
# File c:\Users\bnl429\AppData\Local\anaconda3\envs\fastbarg\Lib\site-packages\EconModel\EconModel.py:253, in EconModelClass.copy(self, name)
#     250 model_dict = self.as_dict()
#     252 # c. initialize
# --> 253 other = self.__class__(name=name)
#     255 # d. fill
#     256 other.from_dict(model_dict,do_copy=True)
#
# File c:\Users\bnl429\AppData\Local\anaconda3\envs\fastbarg\Lib\site-packages\EconModel\EconModel.py:87, in EconModelClass.__init__(self, name, load, from_dict, skip, **kwargs)
#      85         # vi. allocate
#      86         assert hasattr(self,'allocate'), 'the model must have defined an .allocate() method'
# ---> 87         self.allocate()
#      89 else:
#      91     self.from_dict(from_dict)
#
# File e:\THJ\Projects\FastBargaining\Application\DynamicTimeAllocationModel.py:336, in HouseholdModelClass.allocate(self)
#     333 self.setup_grids()
#     335 self.allocate_memory()
# --> 336 self.fill_allocations()
#
# File e:\THJ\Projects\FastBargaining\Application\DynamicTimeAllocationModel.py:593, in HouseholdModelClass.fill_allocations(self)
#     586 _fill(sol, (
#     587     "Cw_tot_single_to_single", "Cm_tot_single_to_single",
#     588     "lw_single_to_single", "lm_single_to_single",
#     589 ), np.nan)
#     591 # ========= b. couples =========
#     592 # b.1 couple -> couple (discrete)
# --> 593 _fill(sol, ("Vwd_couple_to_couple", "Vmd_couple_to_couple"), np.nan)
#     594 sol.Vd_couple_to_couple[...] = -np.inf
#     595 _fill(sol, (
#     596     "Cwd_priv_couple_to_couple", "Cmd_priv_couple_to_couple",
#     597     "Cd_inter_couple_to_couple", "Qd_couple_to_couple",
#    (...)    600     "Cd_tot_couple_to_couple",
#     601 ), np.nan)
#
# File e:\THJ\Projects\FastBargaining\Application\DynamicTimeAllocationModel.py:543, in HouseholdModelClass.fill_allocations.<locals>._fill(obj, names, value)
#     541 def _fill(obj, names, value):
#     542     for n in names:
# --> 543         getattr(obj, n)[...] = value
#
# KeyboardInterrupt:

# %%
# questions to the results below:
# Q1: why is there NO change in the power/divorce when love is now super low?
# Q2: should W_lag and those variables not be [it] and not [it_1]? it is the states today. There is a discrepancy between the way love and the rest is updated. 
#       The idea is that we update next period states in the end of the simulation. This also means that the wage process if of.

# %%
# for var in ('draw_shock_Kw','draw_love','love','Kw','Km','Cw_priv','Cm_priv','C_tot','Qw','hw','hm','lw','lm','couple','power','wage_w','wage_m'):
for var in ('draw_love','love','couple','power'):
    fig,ax = plt.subplots()
    base = np.nanmean(getattr(model.sim,var),axis=0)
    shock = np.nanmean(getattr(model_shock.sim,var),axis=0)
    age = 25+np.arange(base.size)
    # ax.plot(age,shock-base,label='post - base')
    ax.plot(age,base,label='base')
    ax.plot(age,shock,label='post')
    ax.set(title=var,xlabel='age',ylabel='change relative to baseline')
    ax.axvline(age_shock,color='gray',linestyle='--')
    # ax.legend();
