# %% [markdown]
# # This Notebook estimates the model

# %% [markdown]
# ## Settings

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from time import time
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from figure_manager import FigureManager
from plots import *

import DynamicTimeAllocationModel

path = 'output/'

fm = FigureManager(path, use_latex=False)

# c++ settings
do_compile = True
threads = 124

# from EconModel import cpptools
# cpptools.setup_nlopt(folder='cppfuncs/', do_print=True)

# %%
# setup model
settings = { 
       # grid lengths
       # 'T':40,
       # 'num_A': 16,
       # 'num_A_pd': 16,
       # 'num_K': 8,
       # 'num_power': 9,
       # 'num_love': 5,
       # 'num_types': 4,
       # 'num_Ctot': 1024,
       # 'num_marg_u':1024,
       # 'simT': 40,
       # 'simN': 10_000,
       'T':40,
       'num_A': 30,
       'num_A_pd': 30,
       'num_K': 10,
       'num_power': 11,
       'num_love': 11,
       'num_types': 4,
       'num_Ctot': 200,
       'num_marg_u':200,
       'simT': 40,
       'simN': 10_000,
       
       # grid bounds
       'max_A': 300.0,
       'max_A_pd': 300.0,
       'max_Ctot': 300.0,
       'max_K': 10.0,      
       'max_love': 100.0,      

       # accounting
       'beta': 0.98, # Bronson, Haanwinckel, and Mazzocco (2025) / Attanasio, Low, and Sánchez-Marcos (2008)
       'R': 1.03, # Voena (2015) - Jakobsen, Jørgensen and Low (2024) - 1.015 in Attanasio, Low, and Sánchez-Marcos (2008)
       'div_A_share': 0.5, # Bronson (2019) - Voena (2015) estimates something slightly different
       
       # preferences / utility
       'rho': 1.5, # Bronson, Haanwinckel, and Mazzocco (2025) / Attanasio, Low, and Sánchez-Marcos (2008)
       
       # home production
       'zeta'           : 0.40, # Bronson, Haanwinckel, and Mazzocco (2025)
       'omega'          : 0.38, # Bronson, Haanwinckel, and Mazzocco (2025)
       
       # human capital
       'phi_k': 1.0, # Jakobsen, Jørgensen and Low (2024)
       'delta': 0.1, # Jakobsen, Jørgensen and Low (2024) / Keane and Wasi (2016)
       'sigma_K': 0.1, # Jakobsen, Jørgensen and Low (2024)
       'hc_mazzocco': False,
       'delta_mazzocco': -1.0,
       'phi_k_mazzocco': 0.5,
       
       # labor choice
       'available_hours': 1.0, # normalized to one, so that labor supply is a share of available hours
       'full_time_hours': 40.0 / (16 * 7), # ~0.36 (40 hours per week - out of 16 hours per day, 7 days per week) - 40 hours from Bronson, Haanwinckel, and Mazzocco (2025)
       'part_time': 0.5, # as share of full time hours - it seems standard to assume that part time hours are about half of full time hours (Eckstein does it)
       
       # repartnering
       'p_meet': 0.00,
       'type_corr': 0.45, # Bronson, Haanwinckel, and Mazzocco (2025) 
       
       # initial distribution
       'init_couple_share': 0.80, # don't know - maybe allow for remmariage and estimate using moment from Echstein
       'mean_love': 0.0, # normalization
       # initial assets and human capital (see Blundell paper)
       
       # technical settings
       'threads':threads,
       'num_multistart': 0,
       'do_egm': True,
       'interp_method': 'linear',
       'interp_inverse': True,
       'precompute_intratemporal': True,
       'centered_gradient': True,
       'bargaining': 'limited',
       }

model = DynamicTimeAllocationModel.HouseholdModelClass(par=settings) 
model.link_to_cpp(force_compile=do_compile)

# %% [markdown]
# ## Empirical Moments to Match

# %%
# all moments listed here will be used in estimation. Comment out those you do not want to use.
datamoms = dict()

# wages
datamoms['wage_level_w_25_34'] = 40.1
datamoms['wage_level_m_25_34'] = 49.3
datamoms['wage_level_w_35_41'] = 50.4
datamoms['wage_level_m_35_41'] = 67.8

# employment rates
datamoms['employment_rate_w_35_41'] = 64.0 # 70.0
datamoms['employment_rate_m_35_41'] = 88.0 # 85.0
datamoms['work_hours_w'] = 1674.0 / 52.0  # annual hours to weekly hours
datamoms['work_hours_m'] = 2062.0 / 52.0  # annual hours to weekly hours

# # consumption
datamoms['consumption'] = 42.716
# datamoms['consumption_sd'] = 0.538 * 100.0 # https://pubs.aeaweb.org/doi/pdfplus/10.1257/aer.20110236
datamoms['wage_90_10_ratio'] = 5.54 * 1.2505
datamoms['wage_50_10_ratio'] = 2.79 * 1.0533
datamoms['wage_90_50_ratio'] = 1.99 * 1.1872
datamoms['consumption_90_10_ratio'] = 3.33 * 1.0954
datamoms['consumption_50_10_ratio'] = 2.02 * (1.0 - 0.0294)
datamoms['consumption_90_50_ratio'] = 1.65 * 1.1285

# # marriage and divorce rates
datamoms['marriage_rate_35_41'] = 69.0
# datamoms['divorce_rate_35_41'] = 12.0
# datamoms['marriage_rate_25_34'] = 61.0
# datamoms['divorce_rate_25_34'] = 7.0

# Mazzocco moments
datamoms['home_prod_w'] = 1535.0 / 52
datamoms['home_prod_m'] = 1035.0 / 52


# weights
weights = dict()
for mom in ('work_hours_w', 'work_hours_m', 'home_prod_w', 'home_prod_m'):
    pass
    # weights[mom] = 0.01
for mom in (
    'wage_90_10_ratio', 'wage_50_10_ratio', 'wage_90_50_ratio', 
    'consumption_90_10_ratio', 'consumption_50_10_ratio', 'consumption_90_50_ratio'
):
    weights[mom] = 10.0
    
# Dont weigh these moments
for mom in (
    # 'consumption',
    'wage_90_10_ratio', 
    'wage_50_10_ratio', 
    'wage_90_50_ratio', 
    # 'consumption_90_10_ratio', 
    'consumption_50_10_ratio', 
    'consumption_90_50_ratio'
):
    weights[mom] = 0.0

# %% [markdown]
# ## Parameters to estimate

# %%
# parameters to estimate
estpars = {
    # Wages
    'mu': {'guess':3.5172,'lower':1.5,'upper':3.00}, 
    'mu_mult': {'guess':1.0533,'lower':1.0,'upper':3.0},
    'gamma': {'guess':0.0677,'lower':0.001,'upper':0.50},
    'gamma_mult': {'guess':1.1857,'lower':1.0,'upper':3.0},
    'sigma_mu': {'guess':0.1,'lower':0.001,'upper':1.0},
    
    # Disutility from work
    'eta': {'guess':0.5211,'lower':0.1,'upper':4.0},
    'eta_mult': {'guess':1.0,'lower':0.3,'upper':3.0},
    'phi': {'guess':0.7,'lower':0.1,'upper':4.0},
    'phi_mult': {'guess':1.0,'lower':0.3,'upper':3.0},
    
    # Home production
    'alpha': {'guess':1.0,'lower':0.1,'upper':1.9},
    'pi': {'guess':0.5,'lower':0.1,'upper':0.9},
    'lambda_': {'guess':10.0,'lower':1.0,'upper':30.0},
    
    # # Match quality
    'sigma_love': {'guess':0.15,'lower':0.01,'upper':20.5},
    # 'div_cost': {'guess':0.0,'lower':0.0,'upper':500.0},
    
    # 'init_couple_share': {'guess':0.50,'lower':0.0,'upper':1.0},
    # 'mean_love': {'guess':0.0,'lower':-50.0,'upper':50.0},
    
    # other
    # 'rho': {'guess':1.5,'lower':1.0,'upper':3.0},
    # 'zeta': {'guess':0.5,'lower':0.1,'upper':2.0},
    # 'omega': {'guess':0.5,'lower':0.1,'upper':2.0},
    # 'sigma_mu_mult': {'guess':1.0,'lower':0.5,'upper':2.0},
    # 'gamma2': {'guess':-0.0010,'lower':-0.002,'upper':0.0},
    # 'gamma2_mult': {'guess':1.1857,'lower':0.5,'upper':2.5},
}


# set parameters to these values if not estimated
use_fixed_init = True # overwrites initial guesses in estpars if True
fixed = {
    'mu': 1.8019, 
    'mu_mult': 1.0892,
    'gamma': 0.1280,
    'gamma_mult': 1.9599,
    'sigma_mu': 0.5471,
    
    'eta'            : 2.2276,
    'eta_mult'       : 1.2873,
    'phi'            : 2.9610,
    'phi_mult'       : 1.1235,

    'alpha'          : 1.0341,
    'pi'             : 0.5898,
    'lambda_'        : 11.4741,
    
    'sigma_love': 7.2896,
    'div_cost': 0.0,
    
    # 'init_couple_share': 0.77,
    # 'mean_love': 0.0
    
    # 'rho': 1.5,
    # 'zeta'           : 0.40,
    # 'omega'          : 0.38,
    # 'gamma2': 0.0,
    # 'gamma2_mult': 1.0,
    # 'sigma_mu_mult': 1.0,   
}

# %% [markdown]
# ## setup initial guess

# %%
# set fixed parameters and potentially update initial values
for key in fixed.keys():
    if key not in estpars.keys():
        setattr(model.par,key,fixed[key])
    
    else:
        if use_fixed_init:
            estpars[key]['guess'] = fixed[key]

# %%
# check bounds
bounds_ok = True
for key in estpars.keys():
    if estpars[key]['guess']<estpars[key]['lower']:
        print(key,' lower',estpars[key]['guess'])
        bounds_ok = False
    
    if estpars[key]['guess']>estpars[key]['upper']:
        print(key,' upper',estpars[key]['guess'])
        bounds_ok = False

if not bounds_ok:
    stop

# %%
# check initial guess
# theta_init = np.array([estpars[key]['guess'] for key in estpars.keys()])
# obj_init = model.obj_func(theta_init, estpars, datamoms, weights, do_print=True)
# for var in ["draw_shock_Kw", "draw_shock_Km", "draw_love", "draw_meet",
#             "draw_uniform_partner_Kw", "draw_uniform_partner_Km",
#             "draw_uniform_partner_Aw", "draw_uniform_partner_Am",
#             "draw_uniform_partner_type_w", "draw_uniform_partner_type_m",
#             "draw_repartner_love"]:
#     print(f"{var}: {np.mean(getattr(model.sim, var)):2.10f}")

# %%
theta_init = np.array([estpars[key]['guess'] for key in estpars.keys()])
solvars = model.sol.__dict__.keys()
simvars = model.sim.__dict__.keys()

solvars = ("Cwd_tot_single_to_single", "Cmd_tot_single_to_single",
            "Cwd_priv_single_to_single", "Cmd_priv_single_to_single",
            "Cwd_inter_single_to_single", "Cmd_inter_single_to_single",
            "Qwd_single_to_single", "Qmd_single_to_single",
            "lwd_single_to_single", "lmd_single_to_single",
            "hwd_single_to_single", "hmd_single_to_single",
            "pre_Cwd_priv_single", "pre_Cmd_priv_single",
            "pre_Cwd_inter_single", "pre_Cmd_inter_single",
            "pre_Qwd_single", "pre_Qmd_single",
            "pre_hwd_single", "pre_hmd_single",
            "grid_marg_u_single_w", "grid_marg_u_single_m",
            "grid_marg_u_single_w_for_inv", "grid_marg_u_single_m_for_inv",
            "Vw_start_as_couple", "Vm_start_as_couple", "margV_start_as_couple",
            "EVw_start_as_couple", "EVm_start_as_couple", "EmargV_start_as_couple",
            "pre_Cwd_priv_couple", "pre_Cmd_priv_couple",
            "pre_Cd_inter_couple", "pre_Qd_couple",
            "pre_hwd_couple", "pre_hmd_couple",
            "grid_marg_u_couple", "grid_marg_u_couple_for_inv",
            "grid_Cinterp_couple")

objs = []
num = 5
stats_sol = [dict()]*num
stats_sim = [dict()]*num
for i in range(num):
    # for key in estpars.keys():
    #     setattr(model.par,key,estpars[key]['guess'])
    # model.solve()
    objs.append(model.obj_func(theta_init, estpars, datamoms, weights, do_print=False))
    for iv,var in enumerate(solvars):
        stats_sol[i][var] = np.nanmean(getattr(model.sol, var).ravel())
    
    print(objs[i])
    # for iv,var in enumerate(simvars):
    #     stats_sim[i][var] = np.nanmean(getattr(model.sim, var).ravel())
# Out:
# C:\Users\zbk883\AppData\Local\Temp\19\ipykernel_48820\886742736.py:35: RuntimeWarning: Mean of empty slice
#   stats_sol[i][var] = np.nanmean(getattr(model.sol, var).ravel())
# 51.56068104671779
# 51.56068104671779
# 51.56068104671779
# 51.56068104671779
# 51.56068104671779

# %%
# print(objs)
for iv,var in enumerate(solvars):
    diff = stats_sol[0][var] - stats_sol[1][var]
    print(f"{var}: {diff:2.10f} ")
    # if abs(diff) > 1e-8:
    #     print(f"{var}: {diff:2.10f} ")
        
# for iv,var in enumerate(simvars):
#     diff = stats_sim[0][var] - stats_sim[1][var]
#     print(f"{var}: {diff:2.10f} ")
#     if abs(diff) > 1e-8:
#         print(f"{var}: {diff:2.10f} ")
# Out:
# Cwd_tot_single_to_single: 0.0000000000
# Cmd_tot_single_to_single: 0.0000000000
# Cwd_priv_single_to_single: 0.0000000000
# Cmd_priv_single_to_single: 0.0000000000
# Cwd_inter_single_to_single: 0.0000000000
# Cmd_inter_single_to_single: 0.0000000000
# Qwd_single_to_single: 0.0000000000
# Qmd_single_to_single: 0.0000000000
# lwd_single_to_single: nan
# lmd_single_to_single: nan
# hwd_single_to_single: 0.0000000000
# hmd_single_to_single: 0.0000000000
# pre_Cwd_priv_single: 0.0000000000
# pre_Cmd_priv_single: 0.0000000000
# pre_Cwd_inter_single: 0.0000000000
# pre_Cmd_inter_single: 0.0000000000
# pre_Qwd_single: 0.0000000000
# pre_Qmd_single: 0.0000000000
# pre_hwd_single: 0.0000000000
# pre_hmd_single: 0.0000000000
# grid_marg_u_single_w: 0.0000000000
# grid_marg_u_single_m: 0.0000000000
# grid_marg_u_single_w_for_inv: 0.0000000000
# grid_marg_u_single_m_for_inv: 0.0000000000
# Vw_start_as_couple: 0.0000000000
# Vm_start_as_couple: 0.0000000000
# margV_start_as_couple: nan
# ...

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
model.par.num_multistart

# %%
stats[0][var]-stats[1][var]

# %%
obj_initw = model.obj_func(theta_init, estpars, datamoms, weights, do_print=True)
for var in ["draw_shock_Kw", "draw_shock_Km", "draw_love", "draw_meet",
            "draw_uniform_partner_Kw", "draw_uniform_partner_Km",
            "draw_uniform_partner_Aw", "draw_uniform_partner_Am",
            "draw_uniform_partner_type_w", "draw_uniform_partner_type_m",
            "draw_repartner_love"]:
    print(f"{var}: {np.mean(getattr(model.sim, var)):2.10f}")

# %%
# model.save_par('calibrated_par')

# %% [markdown]
# check that solution makes sense

# %%
# from plots import *

# solve


# grid = 'grid_A'
# idx = {'t': 35, 'il':2, 'type': 0, 'iK': 5, 'iP': 5, 'iL': 3, 'iA': 10, 'iA_pd': 10}

# mp = model_plotter(model, model_name='model', titles=['variable'], labels=['model', 'index'])
# fig, ax = fm.create_figure(3,2,6)
# mp.plot_gender_couple_choices(ax, grid=grid, index=idx, alpha=0.5)
# fig.tight_layout()
# fig.show()

# fig, ax = fm.create_figure(4,2,8)
# mp.plot_sim_female(ax, alpha=0.5)
# fig.tight_layout()
# fig.show()

# fig, ax = fm.create_figure(4,2,8)
# mp.plot_sim_female(ax, agg_fct=None ,alpha=0.5)
# fig.tight_layout()
# fig.show()

# fig, ax = fm.create_figure(2,2,4)
# mp.plot_sim_couple(ax ,alpha=0.5)
# fig.tight_layout()
# fig.show()

# fig, ax = fm.create_figure(2,2,4)
# mp.plot_sim_couple(ax, agg_fct=None ,alpha=0.5)
# fig.tight_layout()
# fig.show()

# %% [markdown]
# ## Estimate model

# %%
# DO_GLOBAL = True
# num_points = 5
# num_guess = 2

# if DO_GLOBAL:
#     theta_guesses = model.global_search(estpars, datamoms,weights,num_points,num_guess=num_guess,do_print=False)

#     for i in range(num_guess):
#         model.obj_func(theta_guesses[i],estpars, datamoms,weights, do_print=True)

# %%
# Estimate model using nelder-mead algorithm
do_print = True # Turn off... 
res = minimize(model.obj_func, theta_init, args=(estpars, datamoms,weights,do_print), method='Nelder-Mead',
               options={'xatol': 1e-3, 'fatol': 1e-3, 'disp': True, 'maxiter':5000})

# %%
model.save_par('calibrated_par')
